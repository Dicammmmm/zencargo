# %%
import sqlite3
import pandas as pd
from pathlib import Path

# %%
DATA_ROOT = "../../data"
conn = sqlite3.connect(Path(DATA_ROOT) / "database.db")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 2
#       1 DATA_ROOT = "..data/"
# ----> 2 conn = sqlite3.connect(Path(DATA_ROOT) / "database.db")
#
# OperationalError: unable to open database file

# %% [markdown]
# # Question 1
# ## How many active, non delivered, shipments are currently in

# %%
path = Path("../sql/question_1.sql")

with open(path, "r", encoding="utf-8") as f:
    query = f.read()

df_q1 = pd.read_sql_query(query, conn)
df_q1

# %% [markdown]
# # Question 2
# ## What is the average lead time per mode of transport per trade lane?

# %%
path = Path("../sql/question_2.sql")

with open(path, "r", encoding="utf-8") as f:
    query = f.read()

df_q2 = pd.read_sql_query(query, conn)
df_q2

# %% [markdown]
# # Question 3
# ## Show the shipments where estimated collection to delivery lead time is different to actual collection to delivery lead

# %%
path = Path("../sql/question_3.sql")

with open(path, "r", encoding="utf-8") as f:
    query = f.read()

df_q3 = pd.read_sql_query(query, conn)
df_q3
