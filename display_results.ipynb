# %%
import sqlite3
import pandas as pd
from pathlib import Path

# %%
DATA_ROOT = "./data"
conn = sqlite3.connect(Path(DATA_ROOT) / "database.db")

# %% [markdown]
# # Question 1
# ## How many active, non delivered, shipments are currently in the pipeline

# %%
path = Path("./scripts/sql/question_1.sql")

with open(path, "r", encoding="utf-8") as f:
    query = f.read()

df_q1 = pd.read_sql_query(query, conn)
df_q1
# Out:
#    active
# 0     414

# %% [markdown]
# # Question 2
# ## What is the average lead time per mode of transport per trade lane?

# %%
path = Path("./scripts/sql/question_2.sql")

with open(path, "r", encoding="utf-8") as f:
    query = f.read()

df_q2 = pd.read_sql_query(query, conn)
df_q2
# Out:
#    mode_of_transport origin_country destination_country  n_shipments  \
# 0                Air             CA                  GB            3
# 1                Air             CA                  NL            4
# 2                Air             CN                  CA            1
# 3                Air             CN                  GB           10
# 4                Air             CN                  NL            1
# 5                Air             CN                  US            3
# 6                Air             GB                  US            5
# 7                Air             HK                  GB            4
# 8                Air             IT                  US            2
# 9                Air             KR                  CA            1
# 10               Air             PT                  US            1
# 11               Air             US                  GB           39
# 12               Air             VN                  GB            9
# 13             Ocean             GB                  US            1
# 14              Road             AT                  DE            2
# 15              Road             BE                  GB            2
# 16              Road             CA                  US            2
# 17              Road             CH                  GB            7
# 18              Road             DE                  BE            1
# 19              Road             DE                  DE           10
# 20              Road             DE                  DK            2
# 21              Road             DE                  ES            3
# 22              Road             DE                  FR            3
# 23              Road             DE                  GB            7
# 24              Road             DE                  NL            2
# 25              Road             DE                  NO            4
# 26              Road             DE                  PL            6
# 27              Road             DE                  SE            2
# 28              Road             ES                  GB            7
# 29              Road             ES                  NL            1
# 30              Road             ES                  PL            2
# 31              Road             ES                  RO            1
# 32              Road             FR                  GB            4
# 33              Road             GB                  CH            1
# 34              Road             GB                  DE            1
# 35              Road             GB                  FI            2
# 36              Road             GB                  FR            1
# 37              Road             GB                  GB          162
# 38              Road             GB                  IE            8
# 39              Road             GB                  IT            8
# 40              Road             GB                  NL            7
# 41              Road             GB                  PL            8
# 42              Road             IT                  GB            4
# 43              Road             IT                  IT            1
# 44              Road             IT                  NL            3
# 45              Road             MA                  GB            2
# 46              Road             NL                  DE            4
# 47              Road             NL                  GB           29
# 48              Road             NL                  IT            1
# 49              Road             NL                  NL            2
# 50              Road             PL                  ES            1
# 51              Road             PL                  GB            1
# 52              Road             PL                  IE            3
# 53              Road             PT                  GB            1
# 54              Road             PT                  PT            1
# 55              Road             TR                  GB           74
# 56              Road             US                  CA            5
# 57              Road             US                  US           25
#
#     avg_lead_time_days
# 0             7.666667
# 1             5.750000
# 2            12.000000
# 3             7.300000
# 4             6.000000
# 5             5.000000
# 6             4.800000
# 7            11.250000
# 8             7.000000
# 9             6.000000
# 10            7.000000
# 11            6.564103
# 12            6.000000
# 13            2.000000
# 14            6.000000
# 15            4.000000
# 16            5.000000
# 17            4.428571
# 18            2.000000
# 19            1.600000
# 20            5.000000
# 21            7.000000
# 22           11.666667
# 23            2.428571
# 24            5.000000
# 25            8.000000
# 26            3.575231
# 27            5.000000
# 28            4.642946
# 29            2.024572
# 30            6.000000
# 31            0.000000
# 32            5.250000
# 33            9.000000
# 34            3.103403
# 35           11.500000
# 36            2.000000
# 37            0.172840
# 38            3.000000
# 39            2.000000
# 40            1.285714
# 41            2.750000
# 42            9.000000
# 43            0.000000
# 44            1.666667
# 45           12.000000
# 46            1.000000
# 47            6.413793
# 48            2.000000
# 49            0.704514
# 50            4.000000
# 51            6.500000
# 52            6.333333
# 53            6.000000
# 54            0.000000
# 55            1.864865
# 56            1.600000
# 57            3.920000

# %% [markdown]
# # Question 3
# ## Show the shipments where estimated collection to delivery lead time is different to actual collection to delivery lead

# %%
path = Path("./scripts/sql/question_3.sql")

with open(path, "r", encoding="utf-8") as f:
    query = f.read()

df_q3 = pd.read_sql_query(query, conn)
df_q3
# Out:
#                     cargo_id mode_of_transport  estimated_lead_time_days  \
# 0   QIzAOb6x1a93HB/OgviTww==              Road                         5
# 1   DYXFyN9HD8xj91m0TYmvnw==              Road                         5
# 2   OseZv/Lrm0rlDZZ4rR4hAg==              Road                         5
# 3   9AbnKVTrGXo4apQQgJXh8A==              Road                         5
# 4   Xuei6laV2W58mCE/TSoIyg==              Road                         7
# 5   SHTUvMwP8u6P1cXg/ATOCw==              Road                        10
# 6   AN065wmYnAdbhaKyZaZdlg==              Road                        11
# 7   sFJAswG4CXQr8q6zUwvfMw==              Road                         3
# 8   HhwiKsZmJZpgfl8x0SgxbQ==              Road                         3
# 9   5BPz4UjSp8mN9l5HGt5x5A==              Road                        13
# 10  qxweLCJprxS1RPjJsIfqVg==              Road                         1
# 11  x+diCfww+EsLkn6RvqikgQ==              Road                         3
# 12  QFF6E58wlnQAfPHiz484dA==              Road                         9
# 13  G7Q6As3lBG1QMhNRXjYUJw==              Road                         6
# 14  3o7HUs5rGIf3KfB8HG7v+Q==              Road                         9
# 15  86vY7ZsgpgGcZA46SMGxqQ==              Road                         6
# 16  oeLf0sJmPzzkuqcXWcETbg==               Air                         7
# 17  A8o/ac3ZyHJSIiCgyDuInA==              Road                         4
# 18  2SUDMW5AHUxYkEidBK7u3g==              Road                         7
# 19  iURlSIjq94jOxyqcYAbGNQ==              Road                         4
# 20  iZApYx2KLyDylUALC+jyKw==              Road                         7
# 21  zqy2YcKq7A/wT4556xxPFg==              Road                        14
# 22  7VHELgv19O7t/sqH8/YBXw==              Road                         3
# 23  PetDeGKuIkfbKh4DGoNYHw==              Road                         3
# 24  Iexvy15lWrws7HMvjKj7Hw==              Road                         3
# 25  gHShmfSj++kMsCjaeNdRgw==              Road                         8
# 26  z+WPPZpYaOl+g0PJ76giCg==              Road                         8
# 27  YbEzOJRLOgpKt+9d+fq3yg==              Road                         8
# 28  s7Sjoh5Hssy/nbOmJ0OfMg==              Road                         8
# 29  4kayqDSFT1EPrg/oRuQkkg==              Road                         8
# 30  S+XiGB9NkQvlOmfW9X0jRA==              Road                         8
# 31  UiIg+o/sd2b6hxyvSJtUbw==              Road                         4
# 32  /P+M8bvQ1IxAh7XkrrYQDg==              Road                         4
# 33  2YlVo8RE2A/QLAUSsrF6Lw==              Road                         4
# 34  upKMnd/kGII8llcEq5u/fg==              Road                         4
# 35  D1sRir+jodMYf4YIwXDJ8g==              Road                         4
# 36  KIc3R5x5SpxgTpmVgp6zcg==              Road                         4
# 37  R+arXAn86tpBUMZogMVL8w==              Road                         4
# 38  A6uY/QGBrKmdoWKiwrronQ==              Road                         6
# 39  otnSfFBde1rJg87/37+c0g==               Air                         2
# 40  lriK1R80EbEBE9bZRtb0ew==              Road                         8
# 41  dkL4tCSHgcOEqGELhTIPtw==              Road                         3
# 42  odsZpvkUiAptD8n1r7iYhg==              Road                         6
# 43  zAqE4GkwaB2m1qtPJwMUaw==              Road                         8
# 44  VvMzBchsyQY0X2SwlLCYBg==              Road                         5
#
#     actual_lead_time_days
# 0                       0
# 1                       4
# 2                       4
# 3                       4
# 4                       6
# 5                      11
# 6                      10
# 7                       2
# 8                       2
# 9                       7
# 10                      0
# 11                      2
# 12                      2
# 13                      5
# 14                     10
# 15                      7
# 16                      6
# 17                      3
# 18                      3
# 19                      3
# 20                      6
# 21                     13
# 22                      2
# 23                      2
# 24                      2
# 25                      5
# 26                      5
# 27                      7
# 28                      7
# 29                      7
# 30                      9
# 31                      1
# 32                      1
# 33                      1
# 34                      1
# 35                      1
# 36                      1
# 37                      1
# 38                      2
# 39                      3
# 40                      9
# 41                      2
# 42                      4
# 43                      2
# 44                      4
